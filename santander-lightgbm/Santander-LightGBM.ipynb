# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

# %%
train_df = pd.read_csv('/home/rigone/Dropbox/Workspace/On_GitHub/Auxilary/Large_Input/santander/train.csv')
test_df = pd.read_csv("/home/rigone/Dropbox/Workspace/On_GitHub/Auxilary/Large_Input/santander/test.csv")

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112   2.4669
# 1  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282  15.5765   0.4773
# 2  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800  12.9813   2.1281
# 3  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813  15.1874   3.1656
# 4  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778  19.5542  -0.2860
#
#    var_196  var_197  var_198  var_199
# 0   4.3654  10.7200  15.4722  -8.7197
# 1  -1.4852   9.8714  19.1293 -20.9760
# 2  -7.1086   7.0618  19.8956 -23.1794
# 3   3.9567   9.2295  13.0168  -4.2108
# 4  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %%
features = [c for c in train_df.columns if c not in ['ID_code', 'target']]

# %%
target = train_df['target']

# %%
param = {
    'bagging_freq': 5,  'bagging_fraction': 0.331,  'boost_from_average':'false',   
    'boost': 'gbdt',    'feature_fraction': 0.0405, 'learning_rate': 0.0083,
    'max_depth': -1,    'metric':'auc',             'min_data_in_leaf': 80,     
    'min_sum_hessian_in_leaf': 10.0,'num_leaves': 13,  'num_threads': 8,            
    'tree_learner': 'serial',   'objective': 'binary',       'verbosity': 1
}

# %%
folds = StratifiedKFold(n_splits=15, shuffle=False, random_state=2319)

# %%
features
# Out:
# ['var_0',
#  'var_1',
#  'var_2',
#  'var_3',
#  'var_4',
#  'var_5',
#  'var_6',
#  'var_7',
#  'var_8',
#  'var_9',
#  'var_10',
#  'var_11',
#  'var_12',
#  'var_13',
#  'var_14',
#  'var_15',
#  'var_16',
#  'var_17',
#  'var_18',
#  'var_19',
#  'var_20',
#  'var_21',
#  'var_22',
#  'var_23',
#  'var_24',
#  'var_25',
#  'var_26',
#  'var_27',
#  'var_28',
#  'var_29',
#  'var_30',
#  'var_31',
#  'var_32',
#  'var_33',
#  'var_34',
#  'var_35',
#  'var_36',
#  'var_37',
#  'var_38',
#  'var_39',
#  'var_40',
#  'var_41',
#  'var_42',
#  'var_43',
#  'var_44',
#  'var_45',
#  'var_46',
#  'var_47',
#  'var_48',
#  'var_49',
#  'var_50',
#  'var_51',
#  'var_52',
#  'var_53',
#  'var_54',
#  'var_55',
#  'var_56',
#  'var_57',
#  'var_58',
#  'var_59',
#  'var_60',
#  'var_61',
#  'var_62',
#  'var_63',
#  'var_64',
#  'var_65',
#  'var_66',
#  'var_67',
#  'var_68',
#  'var_69',
#  'var_70',
#  'var_71',
#  'var_72',
#  'var_73',
#  'var_74',
#  'var_75',
#  'var_76',
#  'var_77',
#  'var_78',
#  'var_79',
#  'var_80',
#  'var_81',
#  'var_82',
#  'var_83',
#  'var_84',
#  'var_85',
#  'var_86',
#  'var_87',
#  'var_88',
#  'var_89',
#  'var_90',
#  'var_91',
#  'var_92',
#  'var_93',
#  'var_94',
#  'var_95',
#  'var_96',
#  'var_97',
#  'var_98',
#  'var_99',
#  'var_100',
#  'var_101',
#  'var_102',
#  'var_103',
#  'var_104',
#  'var_105',
#  'var_106',
#  'var_107',
#  'var_108',
#  'var_109',
#  'var_110',
#  'var_111',
#  'var_112',
#  'var_113',
#  'var_114',
#  'var_115',
#  'var_116',
#  'var_117',
#  'var_118',
#  'var_119',
#  'var_120',
#  'var_121',
#  'var_122',
#  'var_123',
#  'var_124',
#  'var_125',
#  'var_126',
#  'var_127',
#  'var_128',
#  'var_129',
#  'var_130',
#  'var_131',
#  'var_132',
#  'var_133',
#  'var_134',
#  'var_135',
#  'var_136',
#  'var_137',
#  'var_138',
#  'var_139',
#  'var_140',
#  'var_141',
#  'var_142',
#  'var_143',
#  'var_144',
#  'var_145',
#  'var_146',
#  'var_147',
#  'var_148',
#  'var_149',
#  'var_150',
#  'var_151',
#  'var_152',
#  'var_153',
#  'var_154',
#  'var_155',
#  'var_156',
#  'var_157',
#  'var_158',
#  'var_159',
#  'var_160',
#  'var_161',
#  'var_162',
#  'var_163',
#  'var_164',
#  'var_165',
#  'var_166',
#  'var_167',
#  'var_168',
#  'var_169',
#  'var_170',
#  'var_171',
#  'var_172',
#  'var_173',
#  'var_174',
#  'var_175',
#  'var_176',
#  'var_177',
#  'var_178',
#  'var_179',
#  'var_180',
#  'var_181',
#  'var_182',
#  'var_183',
#  'var_184',
#  'var_185',
#  'var_186',
#  'var_187',
#  'var_188',
#  'var_189',
#  'var_190',
#  'var_191',
#  'var_192',
#  'var_193',
#  'var_194',
#  'var_195',
#  'var_196',
#  'var_197',
#  'var_198',
#  'var_199']

# %%
oof = np.zeros(len(train_df))

# %%
predictions = np.zeros(len(test_df))

# %%
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df.values, target.values)):
    print("Fold {}".format(fold_))
    trn_data = lgb.Dataset(train_df.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])
    clf = lgb.train(param, trn_data, 1000000, valid_sets = [trn_data, val_data], verbose_eval=5000, early_stopping_rounds = 4000)
    oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
    predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# Fold 0
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924417	valid_1's auc: 0.89887
# [10000]	training's auc: 0.939862	valid_1's auc: 0.901961
# [15000]	training's auc: 0.952448	valid_1's auc: 0.902155
# Early stopping, best iteration is:
# [11245]	training's auc: 0.943199	valid_1's auc: 0.902323
# Fold 1
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.925071	valid_1's auc: 0.89182
# [10000]	training's auc: 0.940421	valid_1's auc: 0.893967
# [15000]	training's auc: 0.952968	valid_1's auc: 0.893958
# Early stopping, best iteration is:
# [13122]	training's auc: 0.948429	valid_1's auc: 0.894314
# Fold 2
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924373	valid_1's auc: 0.901966
# [10000]	training's auc: 0.939811	valid_1's auc: 0.903669
# Early stopping, best iteration is:
# [10639]	training's auc: 0.941514	valid_1's auc: 0.903793
# Fold 3
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.925344	valid_1's auc: 0.885817
# [10000]	training's auc: 0.940676	valid_1's auc: 0.888195
# Early stopping, best iteration is:
# [9820]	training's auc: 0.940191	valid_1's auc: 0.888283
# Fold 4
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.923991	valid_1's auc: 0.907311
# [10000]	training's auc: 0.939612	valid_1's auc: 0.909084
# Early stopping, best iteration is:
# [10447]	training's auc: 0.940836	valid_1's auc: 0.909143
# Fold 5
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924885	valid_1's auc: 0.890998
# [10000]	training's auc: 0.940243	valid_1's auc: 0.892937
# [15000]	training's auc: 0.952849	valid_1's auc: 0.893244
# [20000]	training's auc: 0.963584	valid_1's auc: 0.892751
# Early stopping, best iteration is:
# [16951]	training's auc: 0.957251	valid_1's auc: 0.893433
# Fold 6
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924483	valid_1's auc: 0.89859
# [10000]	training's auc: 0.939893	valid_1's auc: 0.900203
# Early stopping, best iteration is:
# [8519]	training's auc: 0.935779	valid_1's auc: 0.900449
# Fold 7
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924663	valid_1's auc: 0.9
# [10000]	training's auc: 0.94003	valid_1's auc: 0.901299
# [15000]	training's auc: 0.952592	valid_1's auc: 0.901105
# Early stopping, best iteration is:
# [12462]	training's auc: 0.946463	valid_1's auc: 0.90141
# Fold 8
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924296	valid_1's auc: 0.90268
# [10000]	training's auc: 0.939797	valid_1's auc: 0.904284
# Early stopping, best iteration is:
# [10175]	training's auc: 0.940277	valid_1's auc: 0.904326
# Fold 9
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924479	valid_1's auc: 0.900433
# [10000]	training's auc: 0.940039	valid_1's auc: 0.901154
# Early stopping, best iteration is:
# [7350]	training's auc: 0.932242	valid_1's auc: 0.901455
# Fold 10
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924679	valid_1's auc: 0.896229
# [10000]	training's auc: 0.940121	valid_1's auc: 0.898554
# Early stopping, best iteration is:
# [9332]	training's auc: 0.938238	valid_1's auc: 0.89867
# Fold 11
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924418	valid_1's auc: 0.900265
# [10000]	training's auc: 0.939921	valid_1's auc: 0.902745
# Early stopping, best iteration is:
# [10469]	training's auc: 0.941174	valid_1's auc: 0.903004
# Fold 12
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924573	valid_1's auc: 0.902903
# [10000]	training's auc: 0.939911	valid_1's auc: 0.904496
# Early stopping, best iteration is:
# [10050]	training's auc: 0.940053	valid_1's auc: 0.904584
# Fold 13
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924001	valid_1's auc: 0.909293
# [10000]	training's auc: 0.939592	valid_1's auc: 0.911551
# Early stopping, best iteration is:
# [10464]	training's auc: 0.940845	valid_1's auc: 0.911625
# Fold 14
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924931	valid_1's auc: 0.893775
# [10000]	training's auc: 0.940283	valid_1's auc: 0.895707
# [15000]	training's auc: 0.952922	valid_1's auc: 0.89551
# Early stopping, best iteration is:
# [11588]	training's auc: 0.944534	valid_1's auc: 0.895966

# %%
print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
sub = pd.DataFrame({"ID_code": test_df.ID_code.values})
sub["target"] = predictions
sub.to_csv("submission.csv", index=False)
# Out:
# CV score: 0.90053
